# %%
import os

import numpy as np
import torch
from pyro.contrib.examples.util import MNIST
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

# %%
assert pyro.__version__.startswith('1.9.1')
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
smoke_test = 'CI' in os.environ

# %%
# for loading and batching MNIST dataset
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = MNIST(root=root, train=True, transform=trans,
                      download=download)
    test_set = MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, 784)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.softplus(self.fc1(z))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = self.sigmoid(self.fc21(hidden))
        return loc_img

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.fc1 = nn.Linear(784, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = x.reshape(-1, 784)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = torch.exp(self.fc22(hidden))
        return z_loc, z_scale

# %%
# define the model p(x|z)p(z)
def model(self, x):
    # register PyTorch module `decoder` with Pyro
    pyro.module("decoder", self.decoder)
    with pyro.plate("data", x.shape[0]):
        # setup hyperparameters for prior p(z)
        z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
        z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
        # sample from prior (value will be sampled by guide when computing the ELBO)
        z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
        # decode the latent code z
        loc_img = self.decoder(z)
        # score against actual images
        pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

# %%
# define the guide (i.e. variational distribution) q(z|x)
def guide(self, x):
    # register PyTorch module `encoder` with Pyro
    pyro.module("encoder", self.encoder)
    with pyro.plate("data", x.shape[0]):
        # use the encoder to get the parameters used to define q(z|x)
        z_loc, z_scale = self.encoder(x)
        # sample the latent code z
        pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder(z)
            # score against actual images
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %%
def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

# %%
def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %%
# Run options
LEARNING_RATE = 1.0e-3
USE_CUDA = False

# Run only for a single iteration for testing
NUM_EPOCHS = 1 if smoke_test else 100
TEST_FREQUENCY = 5

# %%
train_loader, test_loader = setup_data_loaders(batch_size=256, use_cuda=USE_CUDA)

# clear param store
pyro.clear_param_store()

# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:00<00:00, 33.4MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 1.13MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:00<00:00, 9.70MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 2.25MB/s]
# [epoch 000]  average training loss: 191.1889
# [epoch 000] average test loss: 156.4133
# [epoch 001]  average training loss: 146.7310
# [epoch 002]  average training loss: 133.4112
# [epoch 003]  average training loss: 124.8793
# [epoch 004]  average training loss: 119.4543
# [epoch 005]  average training loss: 115.9527
# [epoch 005] average test loss: 113.9719
# [epoch 006]  average training loss: 113.6128
# [epoch 007]  average training loss: 111.9768
# [epoch 008]  average training loss: 110.7523
# [epoch 009]  average training loss: 109.7787
# [epoch 010]  average training loss: 109.0108
# [epoch 010] average test loss: 107.9884
# [epoch 011]  average training loss: 108.3412
# [epoch 012]  average training loss: 107.7972
# [epoch 013]  average training loss: 107.3430
# [epoch 014]  average training loss: 106.9191
# [epoch 015]  average training loss: 106.5657
# [epoch 015] average test loss: 106.0434
# [epoch 016]  average training loss: 106.2986
# [epoch 017]  average training loss: 106.0221
# [epoch 018]  average training loss: 105.7667
# [epoch 019]  average training loss: 105.5508
# [epoch 020]  average training loss: 105.3351
# [epoch 020] average test loss: 104.9080
# [epoch 021]  average training loss: 105.1821
# [epoch 022]  average training loss: 105.0013
# [epoch 023]  average training loss: 104.8456
# [epoch 024]  average training loss: 104.6964
# [epoch 025]  average training loss: 104.5634
# [epoch 025] average test loss: 104.3859
# [epoch 026]  average training loss: 104.4372
# [epoch 027]  average training loss: 104.3005
# [epoch 028]  average training loss: 104.2155
# [epoch 029]  average training loss: 104.1219
# [epoch 030]  average training loss: 104.0050
# [epoch 030] average test loss: 103.9240
# [epoch 031]  average training loss: 103.8894
# [epoch 032]  average training loss: 103.8045
# [epoch 033]  average training loss: 103.6944
# [epoch 034]  average training loss: 103.6607
# [epoch 035]  average training loss: 103.5369
# [epoch 035] average test loss: 103.5659
# [epoch 036]  average training loss: 103.4866
# [epoch 037]  average training loss: 103.4232
# [epoch 038]  average training loss: 103.3667
# [epoch 039]  average training loss: 103.2542
# [epoch 040]  average training loss: 103.2245
# [epoch 040] average test loss: 103.1895
# [epoch 041]  average training loss: 103.1427
# [epoch 042]  average training loss: 103.0889
# [epoch 043]  average training loss: 103.0543
# [epoch 044]  average training loss: 102.9570
# [epoch 045]  average training loss: 102.9065
# [epoch 045] average test loss: 102.9362
# [epoch 046]  average training loss: 102.8591
# [epoch 047]  average training loss: 102.7953
# [epoch 048]  average training loss: 102.7664
# [epoch 049]  average training loss: 102.7231
# [epoch 050]  average training loss: 102.6531
# [epoch 050] average test loss: 102.6093
# [epoch 051]  average training loss: 102.6123
# [epoch 052]  average training loss: 102.5921
# [epoch 053]  average training loss: 102.5333
# [epoch 054]  average training loss: 102.5231
# [epoch 055]  average training loss: 102.4435
# [epoch 055] average test loss: 102.5532
# [epoch 056]  average training loss: 102.4202
# [epoch 057]  average training loss: 102.3320
# [epoch 058]  average training loss: 102.3633
# [epoch 059]  average training loss: 102.2704
# [epoch 060]  average training loss: 102.2602
# [epoch 060] average test loss: 102.2205
# [epoch 061]  average training loss: 102.1808
# [epoch 062]  average training loss: 102.1218
# [epoch 063]  average training loss: 102.1465
# [epoch 064]  average training loss: 102.0870
# [epoch 065]  average training loss: 102.0466
# [epoch 065] average test loss: 102.3774
# [epoch 066]  average training loss: 102.0185
# [epoch 067]  average training loss: 101.9897
# [epoch 068]  average training loss: 101.9578
# [epoch 069]  average training loss: 101.9123
# [epoch 070]  average training loss: 101.8929
# [epoch 070] average test loss: 102.1017
# [epoch 071]  average training loss: 101.8459
# [epoch 072]  average training loss: 101.7735
# [epoch 073]  average training loss: 101.8079
# [epoch 074]  average training loss: 101.7710
# [epoch 075]  average training loss: 101.7222
# [epoch 075] average test loss: 102.0113
# [epoch 076]  average training loss: 101.6633
# [epoch 077]  average training loss: 101.6699
# [epoch 078]  average training loss: 101.6547
# [epoch 079]  average training loss: 101.6123
# [epoch 080]  average training loss: 101.5829
# [epoch 080] average test loss: 101.8884
# [epoch 081]  average training loss: 101.5568
# [epoch 082]  average training loss: 101.5406
# [epoch 083]  average training loss: 101.5223
# [epoch 084]  average training loss: 101.4543
# [epoch 085]  average training loss: 101.4508
# [epoch 085] average test loss: 101.7151
# [epoch 086]  average training loss: 101.4277
# [epoch 087]  average training loss: 101.3779
# [epoch 088]  average training loss: 101.3714
# [epoch 089]  average training loss: 101.3423
# [epoch 090]  average training loss: 101.2998
# [epoch 090] average test loss: 101.6843
# [epoch 091]  average training loss: 101.2917
# [epoch 092]  average training loss: 101.2766
# [epoch 093]  average training loss: 101.2694
# [epoch 094]  average training loss: 101.2474
# [epoch 095]  average training loss: 101.1998
# [epoch 095] average test loss: 101.4896
# [epoch 096]  average training loss: 101.1298
# [epoch 097]  average training loss: 101.1248
# [epoch 098]  average training loss: 101.1042
# [epoch 099]  average training loss: 101.0897

# %%
import torch
import pyro.distributions as dist

def get_latent_representations(vae, dataloader, device="cpu"):
    vae.eval()  # Set the model to evaluation mode
    latents = []
    labels = []
    
    with torch.no_grad():  # No need to compute gradients
        for x, y in dataloader:  # Assuming (data, labels) from dataloader
            x = x.to(device)
            z_loc, z_scale = vae.encoder(x)  # Get latent distribution parameters
            z = dist.Normal(z_loc, z_scale).sample()  # Sample latent variable
            latents.append(z)
            labels.append(y)
    
    return torch.cat(latents, dim=0), torch.cat(labels, dim=0)

# %%
latents, labels = get_latent_representations(vae, train_loader)

# %%
latents.shape
# Out:
# torch.Size([60000, 50])
